# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy as sp

from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import re

# %%
years = ['2010','2011','2012','2013','2014','2015','2016','2017']
weeks = np.arange(1,18)

# %%
def scrape_teamstats(link1,allcolumns,floatcols,pergame,columnswanted):
    t0 = time.time()
    df_name = pd.DataFrame(columns = allcolumns)
    for y in years:
        link =  link1 + str(y) + "&seasonType=REG&tabSeq=2&qualified=false&Submit=Go"
        html = urlopen(link)
        html = BeautifulSoup(html.read(),'lxml')
        table = html.find('tbody').findAll('tr')

        for x in table:
            td = x.findAll('td')
            listy = []
            listy.append(y)
            count=len(df_name)
            for a in td:
                listy.append(a.text)
            listy= [re.sub('\n','',a) for a in listy]
            listy= [re.sub('\t','',a) for a in listy]
            df_name.loc[count,:]= listy
    
    #make columns floats
    floatcols = floatcols + ['G']
    for a in floatcols:
        df_name[a]=df_name[a].astype(float)
    
    #make some stats per game
    for a in pergame:
        df_name[a] = round(df_name[a] / df_name['G'],2)
    
    #get only columns wanted
    df_name = df_name[columnswanted]
        
    print(time.time() - t0)
    return df_name

# %%
#get team receiving fumbles
link1 = "http://www.nfl.com/stats/categorystats?archive=false&conference=null&role=OPP&offensiveStatisticCategory=null&defensiveStatisticCategory=TEAM_RECEIVING&season="

allcolumnsrec = ['Year','Rk','Team','G','Pts/G','TotPts','Rec','Yds','Avg','Yds/G','Lng','TD',
           '20+','40+', '1st','1st%','FUM']
floatcolsrec = ['FUM']
pergamerec = ['FUM']
columnswantedrec = ['Year','Team','FUM']

dfdrec = scrape_teamstats(link1,allcolumnsrec,floatcolsrec,pergamerec,columnswantedrec)
dfdrec.columns = ['Year','Team','FUMREC']
# Out:
# 4.140455007553101

# %%
#offensive passing

link1 = "http://www.nfl.com/stats/categorystats?archive=true&conference=null&role=TM&offensiveStatisticCategory=TEAM_PASSING&defensiveStatisticCategory=null&season="

#passing info
allcolumnsp = ['Year','Rk','Team','G','Pts/G','TotPts','Comp','Att','Pct','Att/G','Yds','Avg','Yds/G','TD',
            'Int','1st','1st%','Lng','20+','40+','Sck','Rate']
floatcolsp = ['Pts/G','Pct','Avg','Yds/G','TD','Int','Sck','Rate']
pergamep = ['TD','Int','Sck']
columnswantedp = ['Year','Team','Pts/G','Pct','Avg','Yds/G','TD','Int','Sck','Rate']

#assign df name
dfop = scrape_teamstats(link1,allcolumnsp,floatcolsp,pergamep,columnswantedp)
# Out:
# 1.9350810050964355

# %%
#get the team offense rushing averages
link1 = "http://www.nfl.com/stats/categorystats?archive=true&conference=null&role=TM&offensiveStatisticCategory=RUSHING&defensiveStatisticCategory=null&season="

allcolumnsr = ['Year','Rk','Team','G','Pts/G','TotPts','Att','Att/G','Yds','Avg','Yds/G','TD',
            'Lng','1st','1st%','20+','40+','FUM']
floatcolsr = ['Avg','Yds/G','TD','FUM']
pergamer = ['TD','FUM']
columnswantedr = ['Year','Team','Avg','Yds/G','TD','FUM']

#assign df name
dfor = scrape_teamstats(link1,allcolumnsr,floatcolsr,pergamer,columnswantedr)
# Out:
# 1.8749699592590332

# %%
#get the team defense passing averages
link1 = "http://www.nfl.com/stats/categorystats?archive=false&conference=null&role=OPP&offensiveStatisticCategory=null&defensiveStatisticCategory=TEAM_PASSING&season="

#assign df name
dfdp = scrape_teamstats(link1,allcolumnsp,floatcolsp,pergamep,columnswantedp)
# Out:
# 4.737360000610352

# %%
#get the team defense rushing averages
link1 = "http://www.nfl.com/stats/categorystats?archive=false&conference=null&role=OPP&offensiveStatisticCategory=null&defensiveStatisticCategory=RUSHING&season="

#assign df name
dfdr = scrape_teamstats(link1,allcolumnsr,floatcolsr,pergamer,columnswantedr)

#add receiving fumbles to rushing fumbles df
dfdr = dfdr.merge(dfdrec)
dfdr['FUM'] = dfdr['FUM'] + dfdr['FUMREC']
dfdr = dfdr.drop('FUMREC',axis=1)
# Out:
# 4.287297010421753

# %%
#change columns
#off pass
passing_cols = ['Year','Team','Pts/G','Comp%','PassAvg','PassYds','PassTD','Int_Thrown','Sacks_All','QBR']
rushing_cols = ['Year','Team','RushAvg','RushYds','RushTD','Fum']
passingd_cols = ['Year','Team','Pts/G_All','Comp%_All','PassAvg_All','PassYds_All','PassTD_All','Int','Sacks','QBR_All']
rushingd_cols = ['Year','Team','RushAvg_All','RushYds_All','RushTD_All','ForcedFum']
dfop.columns = passing_cols
dfor.columns = rushing_cols
dfdp.columns = passingd_cols
dfdr.columns = rushingd_cols

# %%
#merge dfs into one for each team
df = dfop.merge(dfor)
df = df.merge(dfdp)
df = df.merge(dfdr)

#change team name to name without city
team1 = df['Team'].str.split(' ',expand=True)
team1.loc[team1[2].isnull(),2]=team1.loc[team1[2].isnull(),1]
df['Team']=team1[2]

df.head()
# Out:
#    Year      Team  Pts/G  Comp%  PassAvg  PassYds  PassTD  Int_Thrown  \
# 0  2010     Colts   27.2   66.3      6.9    288.1    2.06        1.06
# 1  2010  Chargers   27.6   66.0      8.7    282.4    1.88        0.81
# 2  2010    Saints   24.0   68.1      7.0    277.6    2.06        1.38
# 3  2010    Texans   24.4   63.6      7.6    259.0    1.50        0.75
# 4  2010   Packers   24.2   65.1      8.0    257.8    1.94        0.81
#
#    Sacks_All    QBR    ...      PassAvg_All  PassYds_All  PassTD_All   Int  \
# 0       1.00   91.9    ...              6.8        214.6        1.38  0.62
# 1       2.38  101.9    ...              6.4        177.8        1.12  1.00
# 2       1.62   90.8    ...              6.8        193.9        0.81  0.56
# 3       2.00   92.0    ...              8.2        267.5        2.06  0.81
# 4       2.38   98.9    ...              6.5        194.2        1.00  1.50
#
#    Sacks  QBR_All  RushAvg_All  RushYds_All  RushTD_All  ForcedFum
# 0   1.88     91.7          4.6        127.0        0.88       0.75
# 1   2.94     76.2          3.7         93.8        0.88       0.43
# 2   2.06     83.2          4.3        112.3        0.81       1.12
# 3   1.88    100.5          4.0        109.4        1.00       0.50
# 4   2.94     67.2          4.7        114.9        0.38       0.69
#
# [5 rows x 26 columns]

# %%
#make df of averages for each year
averages = df.groupby('Year').mean().round(2)
averages
# Out:
#       Pts/G  Comp%  PassAvg  PassYds  PassTD  Int_Thrown  Sacks_All    QBR  \
# Year
# 2010  22.04  60.61     7.00   221.55    1.47        1.00       2.21  83.93
# 2011  22.18  59.85     7.17   229.69    1.45        0.99       2.32  83.77
# 2012  22.75  60.92     7.09   231.28    1.48        0.91       2.28  85.63
# 2013  23.41  61.11     7.13   235.61    1.57        0.98       2.53  86.01
# 2014  22.58  62.54     7.22   236.82    1.58        0.88       2.37  88.71
# 2015  22.81  62.98     7.27   243.81    1.64        0.85       2.32  90.31
# 2016  22.77  62.95     7.17   241.48    1.54        0.81       2.18  89.31
# 2017  21.92  62.96     7.09   226.17    1.52        0.84       2.48  88.71
#
#       RushAvg  RushYds    ...      PassAvg_All  PassYds_All  PassTD_All   Int  \
# Year                      ...
# 2010     4.20   114.47    ...             7.01       221.54        1.47  1.00
# 2011     4.28   117.15    ...             7.21       229.68        1.45  0.99
# 2012     4.23   115.92    ...             7.08       231.29        1.48  0.91
# 2013     4.15   112.88    ...             7.12       235.62        1.57  0.98
# 2014     4.14   111.33    ...             7.22       236.80        1.58  0.88
# 2015     4.12   108.85    ...             7.28       243.82        1.64  0.85
# 2016     4.17   108.91    ...             7.16       241.48        1.54  0.81
# 2017     4.08   109.20    ...             7.05       225.75        1.51  0.84
#
#       Sacks  QBR_All  RushAvg_All  RushYds_All  RushTD_All  ForcedFum
# Year
# 2010   2.21    84.18         4.19       114.47        0.78       0.73
# 2011   2.32    84.51         4.29       117.14        0.78       0.65
# 2012   2.28    85.63         4.25       115.92        0.78       0.69
# 2013   2.53    86.17         4.17       112.87        0.80       0.63
# 2014   2.37    89.09         4.15       111.33        0.74       0.70
# 2015   2.32    90.58         4.12       108.83        0.71       0.69
# 2016   2.18    89.30         4.17       108.91        0.86       0.64
# 2017   2.48    88.27         4.10       108.77        0.67       0.60
#
# [8 rows x 24 columns]

# %%
subtract_list = ['Team','Pts/G_All','Comp%_All','PassAvg_All','PassYds_All','PassTD_All','Int','Sacks','QBR_All',
                'RushAvg_All','RushYds_All','RushTD_All','ForcedFum',
                'Pts/G','Comp%','PassAvg','PassYds','PassTD','Int_Thrown','Sacks_All','QBR',
                'RushAvg','RushYds','RushTD','Fum']

dfavgsub = dfavg[subtract_list]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-465c62b85099> in <module>()
#       4                 'RushAvg','RushYds','RushTD','Fum']
#       5
# ----> 6 dfavgsub = dfavg[subtract_list]
#
# NameError: name 'dfavg' is not defined

# %%
def scrape_schedule(link1):
    t0 = time.time()
    df = pd.DataFrame(columns = ['Year','Week','AwayTeam','AwayScore','HomeTeam','HomeScore'])
    for y in years:
        print(y)
        for w in weeks:
            count=0
            link =  link1 + str(y) + "/REG" + str(w)
            html = urlopen(link)
            html = BeautifulSoup(html.read(),'lxml')
            teamnames = html.findAll('span',{'class':'team-name'})
            teamscores = html.findAll('span',{'class':'team-score'})
            for a in np.arange(0,len(teamnames)/2):
                listy = []
                listy.append(y)
                listy.append(w)
                listy.append(teamnames[count].text)
                if len(teamscores)!=0:
                    listy.append(teamscores[count].text)
                else:
                    listy.append(0)
                listy.append(teamnames[count + 1].text)
                if len(teamscores)!=0:
                    listy.append(teamscores[count + 1].text)
                else:
                    listy.append(0)
                count +=2
                df.loc[len(df),:] = listy
    
    #make integers
    for c in ['Week','AwayScore','HomeScore']:
        df[c] = df[c].astype(int)
    
    print(time.time() - t0)
    return df

# %%
link1 = "http://www.nfl.com/schedules/"
copysched = scrape_schedule(link1)
schedules = copysched.copy()
schedules= schedules[['Year','Week','HomeTeam','HomeScore','AwayTeam','AwayScore']]
# Out:
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 312.1175730228424

# %%
schedules = copysched.copy()
schedules= schedules[['Year','Week','HomeTeam','HomeScore','AwayTeam','AwayScore']]
schedules['Spread'] = schedules['AwayScore'] - schedules['HomeScore']
schedules['Year']=schedules['Year'].astype(str)
schedules.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3cd06f72428a> in <module>()
# ----> 1 schedules = copysched.copy()
#       2 schedules= schedules[['Year','Week','HomeTeam','HomeScore','AwayTeam','AwayScore']]
#       3 schedules['Spread'] = schedules['AwayScore'] - schedules['HomeScore']
#       4 schedules['Year']=schedules['Year'].astype(str)
#       5 schedules.head()
#
# NameError: name 'copysched' is not defined

# %%
intcols= df.columns.drop(['Year','Team'])
homecols = ['H_' + c for c in intcols]
awaycols = ['A_' + c for c in intcols]
hdf = df.copy()
hdf.columns= [['Year', 'HomeTeam'] + homecols]
adf = df.copy()
adf.columns= [['Year','AwayTeam'] + awaycols]
schedules = schedules.merge(hdf)
schedules = schedules.merge(adf)
subtract_dict = {'H_Pts/G':'A_Pts/G_All',
                 'H_Comp%': 'A_Comp%_All',
                 'H_PassAvg': 'A_PassAvg_All',
                 'H_PassYds': 'A_PassYds_All',
                 'H_PassTD': 'A_PassTD_All',
                 'H_Int_Thrown': 'A_Int',
                 'H_Sacks_All': 'A_Sacks',
                 'H_QBR': 'A_QBR_All',
                 'H_RushAvg': 'A_RushAvg_All',
                 'H_RushYds': 'A_RushYds_All',
                 'H_RushTD': 'A_RushTD_All',
                 'H_Fum': 'A_ForcedFum',
                 'H_Pts/G_All': 'A_Pts/G',
                 'H_Comp%_All': 'A_Comp%',
                 'H_PassAvg_All': 'A_PassAvg',
                 'H_PassYds_All': 'A_PassYds',
                 'H_PassTD_All': 'A_PassTD',
                 'H_Int': 'A_Int_Thrown',
                 'H_Sacks': 'A_Sacks_All',
                 'H_QBR_All': 'A_QBR',
                 'H_RushAvg_All': 'A_RushAvg',
                 'H_RushYds_All': 'A_RushYds',
                 'H_RushTD_All': 'A_RushTD',
                 'H_ForcedFum': 'A_Fum',
                 
}


to_percent = ['H_Comp%','H_Comp%_All','A_Comp%','A_Comp%_All']
schedules[to_percent] = schedules[to_percent].apply(lambda x: x/100)

for c in homecols:
    name = 'D' + c
    sub = subtract_dict[c]
    schedules[name] = (schedules[c] + schedules[sub])/2

schedules.head()
# Out:
# Empty DataFrame
# Columns: [Week, HomeTeam, HomeScore, AwayScore, Spread, DH_Pts/G, DH_Comp%, DH_PassAvg, DH_PassYds, DH_PassTD, DH_Int_Thrown, DH_Sacks_All, DH_QBR, DH_RushAvg, DH_RushYds, DH_RushTD, DH_Fum, DH_Pts/G_All, DH_Comp%_All, DH_PassAvg_All, DH_PassYds_All, DH_PassTD_All, DH_Int, DH_Sacks, DH_QBR_All, DH_RushAvg_All, DH_RushYds_All, DH_RushTD_All, DH_ForcedFum, H_Pts/G, H_Comp%, H_PassAvg, H_PassYds, H_PassTD, H_Int_Thrown, H_Sacks_All, H_QBR, H_RushAvg, H_RushYds, H_RushTD, H_Fum, H_Pts/G_All, H_Comp%_All, H_PassAvg_All, H_PassYds_All, H_PassTD_All, H_Int, H_Sacks, H_QBR_All, H_RushAvg_All, H_RushYds_All, H_RushTD_All, H_ForcedFum, Year, AwayTeam, A_Pts/G, A_Comp%, A_PassAvg, A_PassYds, A_PassTD, A_Int_Thrown, A_Sacks_All, A_QBR, A_RushAvg, A_RushYds, A_RushTD, A_Fum, A_Pts/G_All, A_Comp%_All, A_PassAvg_All, A_PassYds_All, A_PassTD_All, A_Int, A_Sacks, A_QBR_All, A_RushAvg_All, A_RushYds_All, A_RushTD_All, A_ForcedFum]
# Index: []
#
# [0 rows x 79 columns]

# %%
newcols = list(map(lambda x: 'D' + x,homecols))
schedules= schedules[['Year','Week','HomeTeam','AwayTeam','HomeScore','AwayScore','Spread'] + newcols]
schedules['Year']=schedules['Year'].astype(int)
schedules.head()
# Out:
#    Year  Week  HomeTeam AwayTeam  HomeScore  AwayScore  Spread  DH_Pts/G  \
# 0  2010     1    Saints  Vikings         14          9      -5     22.90
# 1  2010    10     Bears  Vikings         27         13     -14     21.35
# 2  2010     8  Patriots  Vikings         28         18     -10     27.10
# 3  2010    16    Eagles  Vikings         14         24      10     24.60
# 4  2010    12  Redskins  Vikings         13         17       4     20.35
#
#    DH_Comp%  DH_PassAvg      ...       DH_PassAvg_All  DH_PassYds_All  \
# 0    0.6550        6.85      ...                 6.70          193.75
# 1    0.6105        7.00      ...                 6.60          208.90
# 2    0.6410        7.30      ...                 6.85          226.05
# 3    0.6245        7.10      ...                 6.80          205.20
# 4    0.6030        6.85      ...                 7.05          227.65
#
#    DH_PassTD_All  DH_Int  DH_Sacks  DH_QBR_All  DH_RushAvg_All  \
# 0          0.845   1.090     2.155       75.45            4.35
# 1          0.880   1.465     2.185       71.05            4.05
# 2          1.220   1.590     2.250       74.45            4.30
# 3          1.410   1.530     2.345       74.25            4.30
# 4          1.160   1.250     2.030       78.65            4.50
#
#    DH_RushYds_All  DH_RushTD_All  DH_ForcedFum
# 0          116.85          0.905         0.780
# 1          105.75          0.940         0.880
# 2          114.70          0.810         0.595
# 3          115.90          0.875         0.500
# 4          124.50          0.970         0.630
#
# [5 rows x 31 columns]

# %%
schedules.to_csv('schedules.csv')

# %%
schedules = pd.read_csv('schedules.csv')
schedules = schedules.drop('Unnamed: 0',axis=1)

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(schedules[newcols].corr())

# %% [markdown]
# ### MODELING

# %%
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#get cat codes
sched_cat = schedules.copy()
sched_cat['HomeTeam'] = sched_cat['HomeTeam'].astype('category')
sched_cat['AwayTeam'] = sched_cat['AwayTeam'].astype('category')
cat_columns = sched_cat.select_dtypes(['category']).columns
team_dict = dict(enumerate(sched_cat['HomeTeam'].cat.categories))
sched_cat[cat_columns] = sched_cat[cat_columns].apply(lambda x: x.cat.codes)

#conditions
train_cond = sched_cat['Year'] < 2017
test_cond = sched_cat['Year'] == 2017
#get train and test data
traindata = sched_cat.loc[train_cond]
testdata = sched_cat.loc[test_cond]

#Split X and y
X_train = traindata.drop(['HomeScore','AwayScore','Spread'],axis=1)
y_train = traindata[['AwayScore','HomeScore','Spread']]
X_test = testdata.drop(['AwayScore','HomeScore','Spread'],axis=1)
y_test = testdata[['AwayScore','HomeScore','Spread']]

# %%
clf = DecisionTreeRegressor(min_samples_leaf=5)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=5, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
cond1 = copysched['AwayTeam']=='Patriots'
cond2 = copysched['HomeTeam']=='Jets'
copysched[cond1 & cond2]
# Out:
#       Year  Week  AwayTeam  AwayScore HomeTeam  HomeScore
# 27    2010     2  Patriots         14     Jets         28
# 400   2011    10  Patriots         37     Jets         16
# 674   2012    12  Patriots         49     Jets         19
# 864   2013     7  Patriots         27     Jets         30
# 1258  2014    16  Patriots         17     Jets         16
# 1512  2015    16  Patriots         20     Jets         26
# 1709  2016    12  Patriots         22     Jets         17
# 1875  2017     6  Patriots         24     Jets         17

# %%
games = X_test[['Year','Week','AwayTeam','HomeTeam']].copy()
for c in cat_columns:
    games.loc[:,c] = games.loc[:,c].map(lambda x: team_dict[x])
games = games.join(y_test)
games = games.sort_values('Week')

games['AS'] = clf.predict(X_test)[:,0]
games['HS'] = clf.predict(X_test)[:,1]
games['P_Sp'] = clf.predict(X_test)[:,2]
games['Error'] = (games['Spread'] - games['P_Sp'])
games['Error2'] = (games['Spread'] - games['P_Sp'])**2
games['RightWinner'] = ((games['Spread']<0)&(games['P_Sp']<0))|((games['Spread']>0)&(games['P_Sp']>0))
games = games[games['Week']<8]

# %%
games.pivot_table(index='HomeTeam').sort_values('AS')
# Out:
#                    AS  AwayScore      Error      Error2         HS  HomeScore  \
# HomeTeam
# Seahawks    10.675000  13.500000  -6.287500   76.590312  19.887500  29.000000
# Saints      13.062500  37.000000  19.225000  593.851250  31.287500  36.000000
# Buccaneers  13.219444  16.333333   4.805556  185.918981  24.358333  22.666667
# Falcons     13.377778  22.000000   8.766667  101.126296  22.811111  22.666667
# Texans      14.866071  25.500000  -0.819940  479.089011  21.296131  32.750000
# Bears       17.293056  15.750000   7.406250   60.740156  27.449306  18.500000
# Titans      17.398810  25.000000   3.492063  141.599395  24.224206  28.333333
# Browns      17.955556  20.250000  13.472222  231.883086  23.177778  12.000000
# Lions       18.016667  26.666667   5.697222  323.630579  25.380556  28.333333
# Steelers    18.341667  17.666667   0.200000  960.786667  22.208333  21.333333
# Chargers    18.473214  17.250000   5.256250  532.310156  24.479464  18.000000
# Colts       18.543750  23.500000   8.281250  122.410156  20.825000  17.500000
# Raiders     18.802381  24.250000  -4.354762   68.619615  17.447619  27.250000
# Jets        19.266667  16.666667  -2.992593   52.580412  19.607407  20.000000
# 49ers       19.324074  34.666667  18.250000  409.354167  20.240741  17.333333
# Chiefs      19.466667  19.666667   1.333333   40.346667  24.133333  23.000000
# 49ers       18.033333   4.266667  -7.016667   86.647778     0.250000
# Chargers    21.740741   2.200000  -1.200000   88.800000     0.666667
# Vikings     23.512500  -4.300000  -2.700000  113.380000     0.500000
# Bills       23.736111 -12.486111  11.152778  125.537616     0.666667
# Dolphins    23.940741  -9.340741   6.340741  145.647078     0.333333
# Packers     22.311111  -4.266667  -2.400000  157.987407     0.333333
# Falcons     23.932407  -9.208333   7.208333  171.713542     0.333333
# Jets        20.705556  -0.188889  -8.311111  176.330864     0.250000
# Redskins    24.577778   0.088889  -4.088889  185.437037     0.666667
# Browns      23.013889  -6.430556  -4.569444  196.870949     0.666667
# Eagles      22.527083  -4.906250   8.156250  211.630156     0.250000
# Bears       19.696296  -0.888889 -12.444444  215.185185     0.666667
# Panthers    26.738889 -10.633333  13.633333  235.577778     0.250000
# Chiefs      24.043750  -4.834821  13.834821  274.626993     0.500000
# Cowboys     27.125000  -1.083333   6.416667  277.178241     1.000000
# Ravens      21.000000   4.316667  -7.316667  279.801111     0.750000
# Giants      28.220833  -5.708333   3.708333  281.600694     0.750000
# Steelers    24.843056  -8.912500  13.912500  311.947812     0.250000
# Raiders     22.722222  -2.722222  -1.611111  380.379630     0.333333
# Titans      24.880952  -4.838095  -1.411905  394.713583     0.750000
# Patriots    22.433333  -3.388889  12.722222  448.724815     0.333333
# Saints      27.609821  -6.298214  16.298214  467.449094     0.500000
# Bengals     17.500000   2.544444  -0.544444  493.182593     0.333333
# Cardinals   22.593750   0.625000 -17.875000  552.118056     0.250000
# Jaguars     21.894048  -3.065476  19.815476  585.421910     0.750000
# Broncos     22.566667   9.033333 -24.533333  680.502222     0.000000
# Colts       22.881614  -4.552249 -21.781085  775.465200     0.666667

# %%
games['RightWinner'].value_counts()
# Out:
# True     56
# False    50
# Name: RightWinner, dtype: int64

# %%
np.sqrt(games['Error2'].mean())
# Out:
# 16.385648048104194

# %%
fimp = pd.DataFrame()
fimp['Feature'] = X_test.columns
fimp['Importance'] = clf.feature_importances_
fimp.sort_values('Importance',ascending=False)
# Out:
#            Feature  Importance
# 4         DH_Pts/G    0.287215
# 16    DH_Pts/G_All    0.219233
# 1             Week    0.038488
# 7       DH_PassYds    0.033542
# 21          DH_Int    0.027372
# 9    DH_Int_Thrown    0.027218
# 26   DH_RushTD_All    0.025481
# 2         HomeTeam    0.023506
# 14       DH_RushTD    0.023318
# 3         AwayTeam    0.022193
# 15          DH_Fum    0.020279
# 17    DH_Comp%_All    0.020275
# 22        DH_Sacks    0.019762
# 12      DH_RushAvg    0.019375
# 5         DH_Comp%    0.018444
# 8        DH_PassTD    0.017072
# 19  DH_PassYds_All    0.015692
# 11          DH_QBR    0.015461
# 18  DH_PassAvg_All    0.014946
# 23      DH_QBR_All    0.014897
# 10    DH_Sacks_All    0.014766
# 20   DH_PassTD_All    0.013994
# 13      DH_RushYds    0.013463
# 25  DH_RushYds_All    0.012381
# 6       DH_PassAvg    0.012209
# 24  DH_RushAvg_All    0.012062
# 27    DH_ForcedFum    0.011953
# 0             Year    0.005405

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pandas import unique
import json
from pandas.io.json import json_normalize

# %%
menu = pd.read_csv('menu.csv')
menu.sort_values('Total Fat',ascending=False).head()
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 81  Chicken & Fish                   Chicken McNuggets (20 piece)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
# 28       Breakfast                  Big Breakfast (Large Biscuit)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 82  22.8 oz (646 g)      1880               1060      118.0
# 32  15.3 oz (434 g)      1150                540       60.0
# 81  11.4 oz (323 g)       940                530       59.0
# 31  14.8 oz (420 g)      1090                510       56.0
# 28    10 oz (283 g)       800                470       52.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 82                        182           20.0                            101
# ...

# %%
fig= plt.figure(figsize=(8,8))
ax1= fig.add_subplot(1,1,1)
for cat in menu['Category'].unique():
    
    x = menu['Calories'][menu['Category']==cat]
    y= menu['Total Fat'][menu['Category']==cat]
    ax1.plot(x,y,'o',color=np.random.uniform(size=3),label=cat)

plt.xlabel('Calories')
plt.ylabel('Total Fat')
handles, labels = ax1.get_legend_handles_labels()
plt.legend(handles=handles,loc='upper left')
plt.grid()

# %%
np.random.normal(size=3)
# Out:
# array([-1.11048046,  0.55626757,  1.11213999])

# %%
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)
